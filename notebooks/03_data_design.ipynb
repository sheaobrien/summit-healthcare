# %% [markdown]
# # Summit Healthcare Data Generation Rules
# ## Data Design, Constraints, and Assumptions
#
# 1. Project goal
# 2. Medication order journey
# 3. Table relationships
# 4. Timestamp rules
# 5. Department behavior rules
# 6. Medication behavior rules
# 7. Delay logic
# 8. Data generation plan
