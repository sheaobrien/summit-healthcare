# %% [markdown]
# # Summit Healthcare EDW
# ## Synthetic Data Generation Notebook
#
# This notebook generates synthetic healthcare data for the Summit Healthcare Enterprise Data Warehouse. The output files will be saved as CSVs and later loaded into PostgreSQL.

# %%
import pandas as pd
import random
from faker import Faker
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import random
# ----> 3 from faker import Faker
#       4 from pathlib import Path
#
# ModuleNotFoundError: No module named 'faker'
